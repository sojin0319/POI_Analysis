# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import urllib.request as request
import json
import urllib.request
data= pd.read_csv(r"./POI_list.csv")
data
# Out:
#      사용자 장소
# 0       사천성
# 1       부리또
# 2    디지털정보관
# 3    사회과학대학
# 4        코노
# 5        공차
# 6     토니피시방
# 7       글로리
# 8      럭키쎄븐
# 9       다이소
# 10  GS25편의점
# 11  자연과학대학교
# 12    종합교육관
# 13    지니PC방

# %%
def kakao_search_place(addr):
    api_key = 'KakaoAK 5bc7785bedf372180f58929a0899232f'
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?&query='
    query = urllib.parse.quote(addr)
    result = requests.get(url+query, headers={'Authorization': api_key}).json()
    #print(result)
    results =[]
    if len(result['documents']) != 0:
        for i in range(len(result['documents'])):
            if result['documents'][i]["address_name"] !="":
                results.append(result['documents'][i]["place_name"])
                results.append(result['documents'][i]["category_name"])
                results.append(result['documents'][i]["address_name"])
                results.append(result['documents'][i]["x"])
                results.append(result['documents'][i]["y"])
    else:
        results.append("no results")
    return results

# %%
results = kakao_search_place("미룡동 예원")

# %%
region = "미룡동 "
place = []
addr = []
lat = []
lon = []
for i in range(len(data)):
    results = kakao_search_place("'" +region + data['사용자 장소'][i] +"'")
    if(results[0] != "no results"):
        place.append(results[0])
        addr.append(results[1])
        lat.append(results[3])
        lon.append(results[2])
    else:
        place.append("없음")
        addr.append("없음")
        lat.append("없음")
        lon.append("없음")
    print(i  ,results)
    
data["상호명"] = place
data["주소"] = addr
data["lat"] = lat
data["lon"] = lon
# Out:
# 0 ['사천성', '전북 군산시 미룡동 881-3', '126.687470545182', '35.9450155080699']
# 1 ['no results']
# 2 ['군산대학교 디지털정보관', '전북 군산시 미룡동 290-2', '126.682784733311', '35.9449743765379']
# 3 ['군산대학교 인문대학사회과학대학', '전북 군산시 미룡동 290-2', '126.68028694561', '35.9476354124414']
# 4 ['X코인노래연습장 군산대점', '전북 군산시 미룡동 413', '126.686967845742', '35.9477043924877', '허니코인노래연습장', '전북 군산시 미룡동 875-2', '126.686793683494', '35.9460573771377']
# 5 ['공차 군산대점', '전북 군산시 미룡동 868-2', '126.68558444193', '35.9466292052756']
# 6 ['no results']
# 7 ['글로리마트', '전북 군산시 미룡동 876-1', '126.687074578909', '35.9464961112694', '글로리북카페', '전북 군산시 미룡동 871-2', '126.686674187443', '35.9465671657713']
# 8 ['no results']
# 9 ['다이소 군산대점', '전북 군산시 미룡동 879-1', '126.686322480081', '35.9449764638461', '다이소 군산미룡점', '전북 군산시 미룡동 876-1', '126.68707003188', '35.9465249390188']
# ...

# %%
data
# Out:
#      사용자 장소               상호명                주소               lat  \
# 0       사천성               사천성  전북 군산시 미룡동 881-3  35.9450155080699
# 1       부리또                없음                없음                없음
# 2    디지털정보관      군산대학교 디지털정보관  전북 군산시 미룡동 290-2  35.9449743765379
# 3    사회과학대학  군산대학교 인문대학사회과학대학  전북 군산시 미룡동 290-2  35.9476354124414
# 4        코노     X코인노래연습장 군산대점    전북 군산시 미룡동 413  35.9477043924877
# 5        공차           공차 군산대점  전북 군산시 미룡동 868-2  35.9466292052756
# 6     토니피시방                없음                없음                없음
# 7       글로리             글로리마트  전북 군산시 미룡동 876-1  35.9464961112694
# 8      럭키쎄븐                없음                없음                없음
# 9       다이소          다이소 군산대점  전북 군산시 미룡동 879-1  35.9449764638461
# 10  GS25편의점       GS25 은파유원지점   전북 군산시 미룡동 49-7  35.9507170359958
# 11  자연과학대학교   군산대학교 자연과학대학4호관  전북 군산시 미룡동 290-2  35.9451283285694
# 12    종합교육관       군산대학교 종합교육관  전북 군산시 미룡동 290-2  35.9463546227608
# ...

# %%
data.to_csv("poi.csv", encoding="utf-8")#파일 내보내기

# %%
import requests
import urllib.request
def kakao_reverse_geocode(lat, lon):
    addr_list = []
    roadaddr_list =[]
    building_list =[]
    api_key = 'KakaoAK 5bc7785bedf372180f58929a0899232f'
    url = 'https://dapi.kakao.com/v2/local/geo/coord2address.json?&x=' + str(lon) +'&y=' + str(lat) 
    option = '&sort=distance&input_coord=WGS84'
    result = requests.get(url+option, headers={'Authorization': api_key}).json()
    #print(result)
    match_first = result['documents'][0]
    #print(match_first)
    if match_first["road_address"]== None:
        addr_list.append(match_first["address"]["address_name"])
        roadaddr_list.append("no results")
        building_list.append("no results")
        return addr_list,roadaddr_list,building_list
    else:
        addr_list.append(match_first["address"]["address_name"])
        roadaddr_list.append(match_first["road_address"]["address_name"])
        building_list.append(match_first["road_address"]["building_name"])
        return addr_list, roadaddr_list,building_list

# %%
kakao_reverse_geocode(35.94471788406372, 126.68750190734863)
# Out:
# (['전북 군산시 미룡동 888-12'], ['전라북도 군산시 황룡안길 3-3'], ['예원'])

# %%
def kakao_get_place(addr):
    place = []
    api_key = 'KakaoAK 5bc7785bedf372180f58929a0899232f'
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?&query='
    query = urllib.parse.quote(addr)
    for j in range(1,4):
        result = requests.get(url+query+"&page=" + str(j), headers={'Authorization': api_key}).json()
        if len(result['documents']) != 0:
            for i in range(len(result['documents'])):
                if result['documents'][i]["place_name"] !="":
                    if result['documents'][i]["place_name"] not in place:
                        place.append(result['documents'][i]["place_name"])
        else:
            place.append("no results")
    return place

# %%
kakao_get_place("전북 군산시 미룡동 881-3")
# Out:
# ['사천성']

# %%
center_list = [[35.94498790394176, 126.68602405894886],
 [35.94551958356585, 126.68283153715588],
 [35.9468879699707, 126.68084280831475]]

# %%
center_list = [[35.94534573048051, 126.68571320918907],
 [35.944976382360345, 126.68611933387152],
 [35.94474997610031, 126.68600454647246],
 [35.945374835090924, 126.68474552604279],
 [35.94544826354818, 126.68336691319237]]

# %%
place_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-093ba86ebeee> in <module>
# ----> 1 place_list
#
# NameError: name 'place_list' is not defined

# %%
def kakao_get_addr(addr):
    lat = []
    lon = []
    api_key = 'KakaoAK 5bc7785bedf372180f58929a0899232f'
    url = 'https://dapi.kakao.com/v2/local/search/address.json?&query='
    query = urllib.parse.quote(addr)
    result = requests.get(url+query, headers={'Authorization': api_key}).json()
    lat.append(result["documents"][0]["y"])
    lon.append(result["documents"][0]["x"])
    return lat, lon

# %%
import requests, json 
import urllib.request

google_place_list = []
api_key = 'AIzaSyCFPeMrcPoaJVR64cy2063Pd45Z0Vk56_s'
#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

for i in range(len(center_list)):
    query = urllib.parse.quote(str(center_list[i][0]) +"," + str(center_list[i][1]))
    r = requests.get(url + 'location=' + query + '&radius=20&language=ko&key=' + api_key) 
    x = r.json() 
#print(x)
    for j in range(len(x["results"])):
        google_place_list.append(x["results"][j]["name"])
        print(x["results"][j]["name"])
# Out:
# 군산시
# 대학로
# 군산시
# 환희빌
# 대학로
# 군산시
# Muhan Refill
# 대학로
# 군산시
# 대학로
# 군산시
# 대학로

# %%
google_place_list
# Out:
# ['군산시',
#  '대학로',
#  '군산시',
#  '환희빌',
#  '대학로',
#  '군산시',
#  'Muhan Refill',
#  '대학로',
#  '군산시',
#  '대학로',
#  '군산시',
#  '대학로']

# %%
import requests, json 
import urllib.request

api_key = 'AIzaSyCFPeMrcPoaJVR64cy2063Pd45Z0Vk56_s'
#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

query = urllib.parse.quote("35.94498790394176, 126.68602405894886")
r = requests.get(url + 'location=' + query + '&radius=50&language=ko&key=' + api_key) 
x = r.json() 
#print(x)
for i in range(len(x["results"])):
    print(x["results"][i]["name"])
# Out:
# 군산시
# 햇살 미룡점
# raracost
# 아리따움군산대점
# 환희빌
# GALMURI
# Muhan Refill
# 군산대정문
# 머슬맥휘트니스클럽
# 해피데이PC클럽
# 째즈센터
# 바이킹노래방
# 미니스톱 군산미룡점
# 서일
# 하루오뎅
# 물들이는헤어
# 대학로

# %%
center_list
# Out:
# [[35.94534573048051, 126.68571320918907],
#  [35.944976382360345, 126.68611933387152],
#  [35.94474997610031, 126.68600454647246],
#  [35.945374835090924, 126.68474552604279],
#  [35.94544826354818, 126.68336691319237]]

# %%
center_list = [[35.94541168212891, 126.6828384399414],
 [35.94502852455088, 126.68610895267],
 [35.94499242735476, 126.68613719781234]]

# %%
place_list = []
addr_list = []
for i in range(len(center_list)):
    addr, roadaddr,building = kakao_reverse_geocode(center_list[i][0],center_list[i][1])
    for j in addr:
        addr_list.append(j)
        place = kakao_get_place(j)
        if place[0] == "no results":
            place = building
        print(i+1, "->" ,j)
        print(place)
        place_list.append(place)
# Out:
# 1 -> 전북 군산시 미룡동 290-2
# ['군산대학교', '전북은행 군산대지점', 'GS25 군산대본점', 'CU 군산대도서관점', 'CU 군산대학생회관점', '군산대학교 황룡도서관', '군산대학교 학생생활관 관리동', '군산대학교 디지털정보관', '헌혈의집 군산대센터', '군산대학교 대학본부', '동원문고', '군산대학교 제2학생회관', '군산대학교 중앙도서관', '군산대학교정류소', '한울미디어', 'IBK기업은행365 군산대학교출장소', '군산대학교 박물관', '군산대학교 산업대학원', '더큰도시락 군산대점', '군산대학교 문무관', '사회관', '군산대학교 황룡문화원', '군산 청년해외취업지원센터', '베토벤안경원', '군산대학교 음악관', '군산대학교 간호학과', '군산대생협그라찌에', '비엔트리니티', '군산 대학교 테니스장1', '체험과여행사업단', '카페드림 군산대학교중앙도서관점', '군산시 귀어귀촌지원센터', '군산대학교 종합교육관', '군산대학교 교육대학원', '군산대학교 남문', '군산대학교 자연과학대학4호관', '군산대학교 누리관', '군산대학교 인문대학사회과학대학', '군산대학교 자연과학대학1호관', '군산대학교 평생교육원제2동', '군산대학교 농구장2', '군산대학교 스포츠과학관', '황룡쉼터', '군산대학교 진리관', '전북은행ATM 군산대지점']
# 2 -> 전북 군산시 미룡동 878
# ['no results']
# 3 -> 전북 군산시 미룡동 878
# ['no results']

# %%
from haversine import haversine
dist_list = []
result_place = []
for i in range(len(place_list)):
    dist = 0
    cnt = 0
    for j in range(len(place_list[i])):
        for k in range(len(data)):
            if place_list[i][j] == data["상호명"][k]:
                #print(i, "place_list: ", place_list[i])
                print(i+1, "-> 매칭 장소: ", data["상호명"][k])
                a =[]
                a.append(float(data["lat"][k]))
                a.append(float(data["lon"][k]))
                a = np.array(a)
                dist = haversine(a,np.array(center_list[i]), unit='km')
                #print(dist)
                dist_list.append([dist, data["상호명"][k]])  
    if place_list[i][0] != "no results":
        min_list = min(dist_list)
        result_place.append([addr_list[i], min_list[1]])
    else:
        result_place.append([addr_list[i],0])
# Out:
# 1 -> 매칭 장소:  군산대학교 디지털정보관
# 1 -> 매칭 장소:  군산대학교 종합교육관
# 1 -> 매칭 장소:  군산대학교 자연과학대학4호관
# 1 -> 매칭 장소:  군산대학교 인문대학사회과학대학

# %%
addr_list
# Out:
# ['전북 군산시 미룡동 290-2', '전북 군산시 미룡동 878', '전북 군산시 미룡동 878']

# %%
result_place
# Out:
# [['전북 군산시 미룡동 290-2', '군산대학교 디지털정보관'],
#  ['전북 군산시 미룡동 878', 0],
#  ['전북 군산시 미룡동 878', 0]]

# %%
cluster_list = [[['2019-08-08 21:05:02', 35.94541168212891, 126.6828384399414],
  ['2019-08-08 21:05:07', 35.94541168212891, 126.6828384399414]],
 [['2019-08-08 21:09:58', 35.94502896354523, 126.6861039576194],
  ['2019-08-08 21:14:47', 35.94503021240234, 126.6861114501953],
  ['2019-08-08 21:16:50', 35.94502639770508, 126.6861114501953]],
 [['2019-08-08 21:10:03', 35.94499278927983, 126.6861400572458],
  ['2019-08-08 21:16:55', 35.94499206542969, 126.6861343383789]]]

# %%
result_place
# Out:
# [['전북 군산시 미룡동 290-2', '군산대학교 디지털정보관'],
#  ['전북 군산시 미룡동 878', 0],
#  ['전북 군산시 미룡동 878', 0]]

# %%
min(dist_list)
# Out:
# [0.04886598950827987, '군산대학교 디지털정보관']

# %%
min_value = dist_list[0]
for i in range(len(dist_list)):
    if dist_list[i] <= min_value:
        min_value = dist_list[i]

# %%
print(min_value)
# Out:
# [0.04886598950827987, '군산대학교 디지털정보관']

# %% [markdown]
# # 카드 내역 기반 POI 후보 리스트 생성

# %%
card_data= pd.read_csv(r"./20200308~20210308.csv")
card_data
# Out:
#                     거래일시  구분     거래금액  거래 후 잔액  취급점           내용
# 0    2020.03.08 19:02:17  출금   -7,100  258,760   32    에이비씨커피군산대
# 1    2020.03.08 19:13:56  출금  -10,000  248,760   32      긱스타PC클럽
# 2    2020.03.09 11:13:14  출금     -760  248,000   32          저금통
# 3    2020.03.10 11:10:47  입금      664  248,664   32  카카오뱅크 캐시백지급
# 4    2020.03.10 14:27:12  출금   -6,000  242,664   32   밀크밥버거 군산대리
# ..                   ...  ..      ...      ...  ...          ...
# 771  2021.03.05 20:18:38  출금   -6,000      317   32          정소진
# 772  2021.03.07 04:24:25  입금   10,000   10,317   32        세이프박스
# 773  2021.03.07 04:24:35  출금  -10,000      317   32        카카오페이
# 774  2021.03.08 20:02:41  입금    7,700    8,017   32          장한나
# 775  2021.03.08 22:27:07  입금    9,000   17,017   32          정소진
#
# [776 rows x 6 columns]

# %%
card_data = card_data.drop(card_data.loc[card_data['구분']=='입금'].index)
card_data = card_data.reset_index(drop=True)
card_data = card_data.drop(['구분','거래금액','거래 후 잔액','취급점'], axis=1)

# %%
card_data
# Out:
#                     거래일시          내용
# 0    2020.03.08 19:02:17   에이비씨커피군산대
# 1    2020.03.08 19:13:56     긱스타PC클럽
# 2    2020.03.09 11:13:14         저금통
# 3    2020.03.10 14:27:12  밀크밥버거 군산대리
# 4    2020.03.10 18:17:38      후불교통대금
# ..                   ...         ...
# 525  2021.03.02 13:04:55       커피면회소
# 526  2021.03.02 13:49:12       카카오페이
# 527  2021.03.04 10:24:23       세이프박스
# 528  2021.03.05 20:18:38         정소진
# 529  2021.03.07 04:24:35       카카오페이
#
# [530 rows x 2 columns]

# %%
for i in range(len(result_place)):
    if result_place[i][1] == 0 :
        for j in range(len(cluster_list)):
            for k in range(len(cluster_list[j])):
                date = cluster_list[j][k][0][0:13]
                date = date.replace("-",".")
                search_time = card_data['거래일시'].str.contains(date)
                card_place = card_data[search_time]
        result_place.insert(1,card_place['내용'])

# %%
card_data
# Out:
#                     거래일시          내용
# 0    2020.03.08 19:02:17   에이비씨커피군산대
# 1    2020.03.08 19:13:56     긱스타PC클럽
# 2    2020.03.09 11:13:14         저금통
# 3    2020.03.10 14:27:12  밀크밥버거 군산대리
# 4    2020.03.10 18:17:38      후불교통대금
# ..                   ...         ...
# 525  2021.03.02 13:04:55       커피면회소
# 526  2021.03.02 13:49:12       카카오페이
# 527  2021.03.04 10:24:23       세이프박스
# 528  2021.03.05 20:18:38         정소진
# 529  2021.03.07 04:24:35       카카오페이
#
# [530 rows x 2 columns]

# %%
cluster_list
# Out:
# [[['2019-08-08 21:05:02', 35.94541168212891, 126.6828384399414],
#   ['2019-08-08 21:05:07', 35.94541168212891, 126.6828384399414]],
#  [['2019-08-08 21:09:58', 35.94502896354523, 126.6861039576194],
#   ['2019-08-08 21:14:47', 35.94503021240234, 126.6861114501953],
#   ['2019-08-08 21:16:50', 35.94502639770508, 126.6861114501953]],
#  [['2019-08-08 21:10:03', 35.94499278927983, 126.6861400572458],
#   ['2019-08-08 21:16:55', 35.94499206542969, 126.6861343383789]]]

# %%
date = cluster_list[0][0][0][0:13]
date = date.replace("-",".")
date
# Out:
# '2019.08.08 21'

# %%
card_data['거래일시']
# Out:
# 0      2020.03.08 19:02:17
# 1      2020.03.08 19:13:56
# 2      2020.03.09 11:13:14
# 3      2020.03.10 14:27:12
# 4      2020.03.10 18:17:38
#               ...
# 525    2021.03.02 13:04:55
# 526    2021.03.02 13:49:12
# 527    2021.03.04 10:24:23
# 528    2021.03.05 20:18:38
# 529    2021.03.07 04:24:35
# Name: 거래일시, Length: 530, dtype: object

# %%
search_time = card_data['거래일시'].str.contains(date)
card_place = card_data[search_time]
card_place['내용']
# Out:
# Series([], Name: 내용, dtype: object)

# %%
from collections import Counter

cnt = Counter(card_data['내용'])
cnt
# Out:
# Counter({'에이비씨커피군산대': 5,
#          '긱스타PC클럽': 74,
#          '저금통': 56,
#          '밀크밥버거 군산대리': 10,
#          '후불교통대금': 6,
#          '카카오페이': 88,
#          '미니스톱군산대정문': 14,
#          '파리바게뜨': 7,
#          '올리브영 군산대점': 1,
#          '노다지감자탕': 2,
#          '홈마트 미룡점': 4,
#          '참새방앗간식당': 1,
#          '열린마트': 1,
#          'GS25군산대': 25,
#          '심봉사도로케': 1,
#          '주)스타벅스커피코리': 2,
#          '토스_정소진': 2,
#          '김은희': 1,
#          '다이소군산대점': 23,
#          '김현중내과의원': 1,
#          '미룡종로약국': 1,
#          '명랑시대쌀핫도그': 2,
#          '글로리마트': 10,
#          '세이프박스': 15,
#          '김밥생각미룡점': 1,
#          '(주)한남 여산휴게소': 3,
#          '파리바게뜨옥천점': 1,
#          '세븐일레븐 옥천공단': 1,
#          '빽다방 충북옥천점': 1,
#          '옥천파맥스약국': 1,
#          '토마토앤비주식회사': 1,
#          '이디야커피 대전은행': 1,
#          '시외버스모바일_이비': 1,
#          '서갑선': 2,
#          'NC웨이브 객사점': 3,
#          '장우린': 3,
#          '(주  )맨인': 1,
#          '설빙군산미룡점': 1,
#          '하버브릿지': 1,
# ...

# %%
region = "미룡동 "
place = []
type_list = []
addr = []
lat = []
lon = []
for i in cnt:
    results = kakao_search_place(region + i)
    if(results[0] != "no results"):
        place.append(results[0])
        type_list.append(results[1])
        addr.append(results[2])
        lat.append(results[4])
        lon.append(results[3])

# %%
place
# Out:
# ['긱스타PC클럽',
#  '미니스톱 군산대정문점',
#  '파리바게뜨 군산미룡점',
#  '올리브영 군산대점',
#  '노다지감자탕',
#  '참새방앗간',
#  'GS25 군산대점',
#  '심봉사도로케 군산산북점',
#  '다이소 군산대점',
#  '김현중내과의원',
#  '미룡종로약국',
#  '명랑핫도그 군산나운점',
#  '글로리마트',
#  '김밥생각 미룡점',
#  '하버브릿지',
#  '우가양평해장국 군산미룡점',
#  '로뎀푸드',
#  '군산도시가스 1지역 고객서비스센터',
#  '더리터 군산대점',
#  '장미칼국수 직영점',
#  '카롱하우스',
#  '큰집닭강정 군산대점',
#  '코레일로지스 군산역',
#  '등촌샤브칼국수 군산점',
#  '파스토',
#  'GS25 군산대후문점',
#  '롯데마트 군산점',
#  '더리터 군산대점',
#  '고은미래의원 군산점',
#  '동일식당',
#  '커피면회소',
#  '카페베네 군산은파호수점',
#  '맥도날드 군산나운DT점',
#  '연합건축인력',
#  '앤티앤스프레즐 이마트군산점',
#  '한신포차 군산수송점',
#  'CU 군산대점',
#  '요리조리',
#  '미니스톱 군산대점',
#  '뚜레쥬르 군산대점',
#  '배스킨라빈스 군산대점',
#  '지니PC방 미룡점',
#  '오산상회']

# %%
user_df = pd.DataFrame({'상호명': place, '유형':type_list,'주소':addr, 'lat':lat, 'lon':lon})
user_df
# Out:
#                    상호명                            유형                  주소  \
# 0              긱스타PC클럽        가정,생활 > 여가시설 > 게임방,PC방    전북 군산시 미룡동 879-1
# 1          미니스톱 군산대정문점            가정,생활 > 편의점 > 미니스톱    전북 군산시 미룡동 879-1
# 2          파리바게뜨 군산미룡점    음식점 > 간식 > 제과,베이커리 > 파리바게뜨    전북 군산시 미룡동 879-2
# 3            올리브영 군산대점          가정,생활 > 드럭스토어 > 올리브영    전북 군산시 미룡동 879-2
# 4               노다지감자탕                음식점 > 한식 > 감자탕    전북 군산시 미룡동 364-5
# 5                참새방앗간              음식점 > 한식 > 육류,고기   전북 군산시 나운동 1537-1
# 6            GS25 군산대점            가정,생활 > 편의점 > GS25    전북 군산시 미룡동 879-2
# 7         심봉사도로케 군산산북점                 음식점 > 간식 > 도넛   전북 군산시 산북동 3562-2
# 8             다이소 군산대점           가정,생활 > 생활용품점 > 다이소    전북 군산시 미룡동 879-1
# 9              김현중내과의원               의료,건강 > 병원 > 내과    전북 군산시 미룡동 880-1
# 10              미룡종로약국                    의료,건강 > 약국    전북 군산시 미룡동 880-1
# 11         명랑핫도그 군산나운점           음식점 > 패스트푸드 > 명랑핫도그    전북 군산시 나운동 156-3
# ...

# %%
miryong = user_df['주소'].str.contains("전북 군산시 미룡동")
user_df = user_df[miryong]
user_df = user_df.reset_index(drop=True)
user_df
# Out:
#                    상호명                          유형                 주소  \
# 0              긱스타PC클럽      가정,생활 > 여가시설 > 게임방,PC방   전북 군산시 미룡동 879-1
# 1          미니스톱 군산대정문점          가정,생활 > 편의점 > 미니스톱   전북 군산시 미룡동 879-1
# 2          파리바게뜨 군산미룡점  음식점 > 간식 > 제과,베이커리 > 파리바게뜨   전북 군산시 미룡동 879-2
# 3            올리브영 군산대점        가정,생활 > 드럭스토어 > 올리브영   전북 군산시 미룡동 879-2
# 4               노다지감자탕              음식점 > 한식 > 감자탕   전북 군산시 미룡동 364-5
# 5            GS25 군산대점          가정,생활 > 편의점 > GS25   전북 군산시 미룡동 879-2
# 6             다이소 군산대점         가정,생활 > 생활용품점 > 다이소   전북 군산시 미룡동 879-1
# 7              김현중내과의원             의료,건강 > 병원 > 내과   전북 군산시 미룡동 880-1
# 8               미룡종로약국                  의료,건강 > 약국   전북 군산시 미룡동 880-1
# 9                글로리마트                가정,생활 > 슈퍼마켓   전북 군산시 미룡동 876-1
# 10            김밥생각 미룡점                    음식점 > 분식   전북 군산시 미룡동 880-1
# 11       우가양평해장국 군산미룡점    음식점 > 한식 > 해장국 > 우가양평해장국   전북 군산시 미룡동 360-2
# ...

# %%
user_df.to_csv("user_poi.csv", encoding='utf-8-sig', index = None)#파일 내보내기

# %%
import pandas as pd
data_df = pd.read_csv(r"./poi.csv",encoding='utf-8')
data_df = data_df.drop(['사용자 장소'],axis = 1)
data_df = data_df.drop(data_df.loc[data_df['주소']=='없음'].index)
data_df = data_df.reset_index(drop=True)
data_df
# Out:
#     Unnamed: 0               상호명                주소               lat  \
# 0            0               사천성  전북 군산시 미룡동 881-3  35.9450155080699
# 1            2      군산대학교 디지털정보관  전북 군산시 미룡동 290-2  35.9449743765379
# 2            3  군산대학교 인문대학사회과학대학  전북 군산시 미룡동 290-2  35.9476354124414
# 3            4     X코인노래연습장 군산대점    전북 군산시 미룡동 413  35.9477043924877
# 4            5           공차 군산대점  전북 군산시 미룡동 868-2  35.9466292052756
# 5            7             글로리마트  전북 군산시 미룡동 876-1  35.9464961112694
# 6            9          다이소 군산대점  전북 군산시 미룡동 879-1  35.9449764638461
# 7           10       GS25 은파유원지점   전북 군산시 미룡동 49-7  35.9507170359958
# 8           11   군산대학교 자연과학대학4호관  전북 군산시 미룡동 290-2  35.9451283285694
# 9           12       군산대학교 종합교육관  전북 군산시 미룡동 290-2  35.9463546227608
# 10          13         지니PC방 미룡점  전북 군산시 미룡동 866-2  35.9474155725387
#
#                  lon
# 0   126.687470545182
# 1   126.682784733311
# 2    126.68028694561
# 3   126.686967845742
# 4    126.68558444193
# ...

# %%
user_df = pd.read_csv(r"./user_poi.csv",encoding='utf-8')
user_df
# Out:
#                    상호명                 주소        lat         lon
# 0         다사랑치킨피자 군산대점     전북 군산시 미룡동 395  35.946259  126.687725
# 1             다이소 군산대점   전북 군산시 미룡동 879-1  35.944976  126.686323
# 2              코봉이무한리필   전북 군산시 미룡동 416-4  35.947596  126.685909
# 3             산쪼메 군산대점   전북 군산시 미룡동 873-2  35.946050  126.686008
# 4         역전할머니맥주 군산대점   전북 군산시 미룡동 875-2  35.946214  126.686739
# 5              공차 군산대점   전북 군산시 미룡동 868-2  35.946629  126.685584
# 6              CU 군산대점   전북 군산시 미룡동 867-5  35.947252  126.686447
# 7            맘스터치 군산대점   전북 군산시 미룡동 868-2  35.946521  126.685558
# 8         부대통령뚝배기 군산대점   전북 군산시 미룡동 881-2  35.945019  126.687271
# 9                글로리마트   전북 군산시 미룡동 876-1  35.946496  126.687075
# 10           쉼표맥주 군산대점   전북 군산시 미룡동 871-1  35.947014  126.686621
# 11           미니스톱 군산대점   전북 군산시 미룡동 867-3  35.947414  126.686659
# 12         파리바게뜨 군산미룡점   전북 군산시 미룡동 879-2  35.945372  126.686808
# ...

# %%
poi_df= pd.concat([data_df,user_df], ignore_index=True)
poi_df
# Out:
#                    상호명                 주소               lat               lon
# 0                  사천성   전북 군산시 미룡동 881-3  35.9450155080699  126.687470545182
# 1         군산대학교 디지털정보관   전북 군산시 미룡동 290-2  35.9449743765379  126.682784733311
# 2     군산대학교 인문대학사회과학대학   전북 군산시 미룡동 290-2  35.9476354124414   126.68028694561
# 3        X코인노래연습장 군산대점     전북 군산시 미룡동 413  35.9477043924877  126.686967845742
# 4              공차 군산대점   전북 군산시 미룡동 868-2  35.9466292052756   126.68558444193
# 5                글로리마트   전북 군산시 미룡동 876-1  35.9464961112694  126.687074578909
# 6             다이소 군산대점   전북 군산시 미룡동 879-1  35.9449764638461  126.686322480081
# 7          GS25 은파유원지점    전북 군산시 미룡동 49-7  35.9507170359958  126.692471358205
# 8      군산대학교 자연과학대학4호관   전북 군산시 미룡동 290-2  35.9451283285694  126.681024103774
# 9          군산대학교 종합교육관   전북 군산시 미룡동 290-2  35.9463546227608  126.681254142961
# 10           지니PC방 미룡점   전북 군산시 미룡동 866-2  35.9474155725387  126.685770854943
# ...

# %%
poi_df.to_csv("poi_candidate2.csv", encoding='utf-8-sig', index = None)#파일 내보내기
